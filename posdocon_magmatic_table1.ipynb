# %% [markdown]
# <a href="https://colab.research.google.com/github/lszam/potentials-on/blob/main/posdocon_magmatic_table1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = [
    {
        "Reference": "Almeida et al. (2021)",
        "Tectonic Phase": "Pre/Syn-Rift",
        "Location": "Santos Basin (Central Coast)",
        "Rock Type": "Tholeiitic dikes",
        "Mantle Source": "Enriched SCLM",
        "Crustal/Lithospheric Contamination": "Yes – La/Nb > 1, negative εNd, Nb trough",
        "Magmatic Residence": "Yes – fractional crystallization, crystal accumulation",
        "Age (Ma)": "≈129–126",
        "Initial Age (Ma)": 129
    },
    {
        "Reference": "Comin-Chiaramonti et al. (2015)",
        "Tectonic Phase": "Pre/Syn-Rift",
        "Location": "Campos Basin (Cabiúnas Fm.)",
        "Rock Type": "Tholeiitic basalts",
        "Mantle Source": "SCLM + asthenospheric component",
        "Crustal/Lithospheric Contamination": "Yes – evolved isotopes, La/Nb > 1",
        "Magmatic Residence": "Possible – compositional evolution suggests residence",
        "Age (Ma)": "≈130",
        "Initial Age (Ma)": 130
    },
    {
        "Reference": "Valente et al. (2017)",
        "Tectonic Phase": "Pre/Syn-Rift",
        "Location": "Cabo Frio High",
        "Rock Type": "Transitional basaltic dikes",
        "Mantle Source": "SCLM (EM1-like)",
        "Crustal/Lithospheric Contamination": "Yes – negative εNd, La/Nb > 1",
        "Magmatic Residence": "Indirect evidence (texture/chemistry)",
        "Age (Ma)": "≈129–127",
        "Initial Age (Ma)": 129
    },
    {
        "Reference": "Lobo et al. (2006)",
        "Tectonic Phase": "Pre/Syn-Rift",
        "Location": "Campos and Pelotas Basins",
        "Rock Type": "Tholeiitic basalts",
        "Mantle Source": "Campos: SCLM; Pelotas: depleted asthenosphere",
        "Crustal/Lithospheric Contamination": "Yes – high Th/Yb and La/Nb",
        "Magmatic Residence": "Yes – compositional evolution",
        "Age (Ma)": "≈132–128",
        "Initial Age (Ma)": 132
    },
    {
        "Reference": "Dani et al. (2017)",
        "Tectonic Phase": "Post-Rift (pre-evaporitic)",
        "Location": "Campos Basin",
        "Rock Type": "Subalkaline tholeiitic basalts",
        "Mantle Source": "Mantle source related to Paraná–Etendeka CFB",
        "Crustal/Lithospheric Contamination": "No – no signs of crustal contamination",
        "Magmatic Residence": "Not assessed",
        "Age (Ma)": "≈121–117",
        "Initial Age (Ma)": 121
    },
    {
        "Reference": "Wang et al. (2024)",
        "Tectonic Phase": "Post-Rift",
        "Location": "Santos Basin (Well Y)",
        "Rock Type": "Basalts and diabases",
        "Mantle Source": "Asthenosphere + SCLM mixture",
        "Crustal/Lithospheric Contamination": "Partial – mixed sources in younger samples",
        "Magmatic Residence": "Yes – partial melting and petrological evolution",
        "Age (Ma)": "≈126–121",
        "Initial Age (Ma)": 126
    },
    {
        "Reference": "Louback et al. (2023)",
        "Tectonic Phase": "Post-Rift (Bacalhau Field)",
        "Location": "Santos Basin",
        "Rock Type": "Tholeiitic basalts",
        "Mantle Source": "Enriched SCLM (EM1)",
        "Crustal/Lithospheric Contamination": "No – no juvenile crustal signal",
        "Magmatic Residence": "Not evaluated",
        "Age (Ma)": "≈116–110",
        "Initial Age (Ma)": 116
    },
    {
        "Reference": "de Barros et al. (2023)",
        "Tectonic Phase": "Post-Rift (Santonian–Campanian)",
        "Location": "Cabo Frio High",
        "Rock Type": "Alkaline basalts and foidites",
        "Mantle Source": "N-MORB + SCLM mixture",
        "Crustal/Lithospheric Contamination": "Partial – mixed mantle sources",
        "Magmatic Residence": "Evidence of pre-intrusion evolution",
        "Age (Ma)": "≈85–75",
        "Initial Age (Ma)": 85
    },
    {
        "Reference": "Scribelk & Valente (2023)",
        "Tectonic Phase": "Post-Rift (Late Aptian)",
        "Location": "Santos Basin",
        "Rock Type": "Alkaline basalts (OIB-type)",
        "Mantle Source": "Asthenospheric plume (Tristan da Cunha)",
        "Crustal/Lithospheric Contamination": "No – La/Nb < 1, positive εNd",
        "Magmatic Residence": "No – rapid ascent",
        "Age (Ma)": "≈117",
        "Initial Age (Ma)": 117
    },
    {
        "Reference": "Braga et al. (2023)",
        "Tectonic Phase": "Pre/Syn-Rift",
        "Location": "Campos Basin – Cabo Frio (Cabiúnas Fm.)",
        "Rock Type": "Tholeiitic lava flows and intrusions",
        "Mantle Source": "Enriched SCLM with crustal interaction",
        "Crustal/Lithospheric Contamination": "Yes – La/Nb > 1, Nb trough, AFC modeling",
        "Magmatic Residence": "Yes – residence in shallow reservoirs",
        "Age (Ma)": "≈134–116",
        "Initial Age (Ma)": 134
    },
    {
        "Reference": "Moreira (2006); Oreiro et al. (2008)",
        "Tectonic Phase": "Post‑Rift Drift (Paleocene–Eocene)",
        "Location": "Cabo Frio High / Southern Santos Basin",
        "Rock Type": "Basalts, diabases, volcanoclastic",
        "Mantle Source": "SCLM + asthenosphere",
        "Crustal/Lithospheric Contamination": "Yes – alkaline mixed signature",
        "Magmatic Residence": "Possible – AFC evolution",
        "Age (Ma)": "≈50–40",
        "Initial Age (Ma)": 50
    }
]


df = pd.DataFrame(data)
df.sort_values(by='Initial Age (Ma)', inplace=True)

df.to_csv('magmatic-table_2.csv', index=False)
df.style.set_properties(**{'text-align': 'left'})
df
# Out:
#                                Reference                      Tectonic Phase  \
# 10  Moreira (2006); Oreiro et al. (2008)  Post‑Rift Drift (Paleocene–Eocene)
# 7                de Barros et al. (2023)     Post-Rift (Santonian–Campanian)
# 6                  Louback et al. (2023)          Post-Rift (Bacalhau Field)
# 8              Scribelk & Valente (2023)             Post-Rift (Late Aptian)
# 4                     Dani et al. (2017)          Post-Rift (pre-evaporitic)
# 5                     Wang et al. (2024)                           Post-Rift
# 2                  Valente et al. (2017)                        Pre/Syn-Rift
# 0                  Almeida et al. (2021)                        Pre/Syn-Rift
# 1        Comin-Chiaramonti et al. (2015)                        Pre/Syn-Rift
# 3                     Lobo et al. (2006)                        Pre/Syn-Rift
# 9                    Braga et al. (2023)                        Pre/Syn-Rift
#
# ...

# %%
# CSV
csv_path = "magma_comparison_table.csv"
df.to_csv(csv_path, index=False)
print(f"CSV file saved: {csv_path}")

# Excel
excel_path = "magma_comparison_table.xlsx"
df.to_excel(excel_path, index=False)
print(f"Excel file saved: {excel_path}")

# Download
from google.colab import files
files.download(csv_path)
files.download(excel_path)
# Out:
# CSV file saved: magma_comparison_table.csv
# Excel file saved: magma_comparison_table.xlsx
